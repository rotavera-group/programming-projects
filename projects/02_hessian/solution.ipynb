# %%
# 1. Generate a starting structure from a SMILES string using `protomol`
from protomol import smiles

smi = "C[CH2]"  # SMILES formula for propyl radical

# Generate a geometry for the SMILES formula
geo = smiles.geometry(smi)

# %%
# 2. Optimize the structure with GFN2-xTB using `qcop`
import qcio
import qcop
from protomol import qc

struc = qc.struc.from_geometry(geo)
prog_inp = qcio.ProgramInput(
    structure=struc, calctype="optimization", model={"method": "gfn2"}
)
prog_out = qcop.compute("crest", prog_inp)

equilibrium_structure = prog_out.results.final_structure

# %%
# 3. By displacing the equilibrium structure and running energy calculations,
# calculate the Hessian of the PES at equilibrium.
import numpy
import functools
from protomol import geom
from numpy.typing import ArrayLike


def coordinate_count(geo: geom.Geometry) -> int:
    """Count number of coordinates in geometry.

    (Generic function that could be added to protomol.geom.)

    :param geo: Geometry
    :return: Number of coordinates
    """
    return geom.count(geo) * 3


def displace(geo: geom.Geometry, disp: ArrayLike) -> geom.Geometry:
    """Displace geometry by arbitrary coordinate vector.

    (Generic function that could be added to protomol.geom.)

    :param geo: Geometry
    :param disp: Displacement vector
    :return: Displaced geometry
    """
    geo = geo.model_copy()
    natms = geom.count(geo)
    geo.coordinates = geo.coordinates + numpy.reshape(disp, (natms, 3))
    return geo


def step_displace_coordinate(
    geo: geom.Geometry, idx: int, step: int = 1, step_size: float = 0.005
) -> geom.Geometry:
    """Step-displace geometry coordinate.

    (Project-specific helper function that could be added to util.py)

    :param geo: Geometry
    :param idx: Flat coordinate index, 0, 1, ..., 3 * n
    :param step: Number of steps to displace (positive or negative)
    :param step_size: Displacement step size
    :return: Geometry
    """
    ncoord = coordinate_count(geo)
    disp = numpy.eye(ncoord, ncoord)[idx] * step * step_size
    return displace(geo, disp)


def hessian(
    prog: str, ene_inp: qcio.ProgramInput, step_size: float = 0.005
) -> numpy.ndarray:
    # Get initial input and reference geometry
    ene_inp0 = ene_inp.model_copy()
    geo0 = qc.struc.geometry(ene_inp0.structure)

    # Define a function to calculate the energy of a given displacement
    @functools.cache
    def energy(idx: int = 0, step: int = 0, idx2: int = 0, step2: int = 0):
        print(
            f"Calculating energy for idx1={idx}, step1={step}, idx2={idx2}, step2={step2}"
        )
        # Generate displaced geometry
        geo = step_displace_coordinate(geo0, idx=idx, step=step, step_size=step_size)
        geo = step_displace_coordinate(geo, idx=idx2, step=step2, step_size=step_size)
        # Copy energy input and replace with displaced geometry
        ene_inp = ene_inp0.model_copy(update={"structure": qc.struc.from_geometry(geo)})
        ene_out = qcop.compute(prog, ene_inp)
        return ene_out.results.energy

    # Create an empty Hessian matrix
    ncoord = coordinate_count(geo)
    hess = numpy.zeros((ncoord, ncoord))

    # Calculate diagonal elements of Hessian matrix
    for idx in range(ncoord):
        hess[idx, idx] = (
            energy(idx=idx, step=+1) + energy(idx=idx, step=-1) - 2 * energy()
        ) / (step_size**2)

    # Calculate off-diagonal elements of Hessian matrix
    # (Iterate over lower triangle to avoid )
    # Then, calculate off-diagonals (iterate over lower triangle)
    for idx1 in range(ncoord):
        for idx2 in range(idx1):
            hess[idx1, idx2] = hess[idx2, idx1] = (
                energy(idx=idx1, step=+1, idx2=idx2, step2=+1)
                + energy(idx=idx1, step=-1, idx2=idx2, step2=-1)
                - energy(idx=idx1, step=+1)
                - energy(idx=idx1, step=-1)
                - energy(idx=idx2, step=+1)
                - energy(idx=idx2, step=-1)
                + 2 * energy()
            ) / (2 * step_size**2)

    return hess


ene_inp = qcio.ProgramInput(
    structure=equilibrium_structure, calctype="energy", model={"method": "gfn2"}
)
hess = hessian("crest", ene_inp=ene_inp)
print(hess)
# Out:
# Calculating energy for idx1=0, step1=1, idx2=0, step2=0
# Calculating energy for idx1=0, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=0, step1=0, idx2=0, step2=0
# Calculating energy for idx1=1, step1=1, idx2=0, step2=0
# Calculating energy for idx1=1, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=2, step1=1, idx2=0, step2=0
# Calculating energy for idx1=2, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=3, step1=1, idx2=0, step2=0
# Calculating energy for idx1=3, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=4, step1=1, idx2=0, step2=0
# Calculating energy for idx1=4, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=5, step1=1, idx2=0, step2=0
# Calculating energy for idx1=5, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=6, step1=1, idx2=0, step2=0
# Calculating energy for idx1=6, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=7, step1=1, idx2=0, step2=0
# Calculating energy for idx1=7, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=8, step1=1, idx2=0, step2=0
# Calculating energy for idx1=8, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=9, step1=1, idx2=0, step2=0
# Calculating energy for idx1=9, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=10, step1=1, idx2=0, step2=0
# Calculating energy for idx1=10, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=11, step1=1, idx2=0, step2=0
# Calculating energy for idx1=11, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=12, step1=1, idx2=0, step2=0
# Calculating energy for idx1=12, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=13, step1=1, idx2=0, step2=0
# Calculating energy for idx1=13, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=14, step1=1, idx2=0, step2=0
# Calculating energy for idx1=14, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=15, step1=1, idx2=0, step2=0
# Calculating energy for idx1=15, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=16, step1=1, idx2=0, step2=0
# Calculating energy for idx1=16, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=17, step1=1, idx2=0, step2=0
# Calculating energy for idx1=17, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=18, step1=1, idx2=0, step2=0
# Calculating energy for idx1=18, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=19, step1=1, idx2=0, step2=0
# Calculating energy for idx1=19, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=20, step1=1, idx2=0, step2=0
# Calculating energy for idx1=20, step1=-1, idx2=0, step2=0
# Calculating energy for idx1=1, step1=1, idx2=0, step2=1
# Calculating energy for idx1=1, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=2, step1=1, idx2=0, step2=1
# Calculating energy for idx1=2, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=2, step1=1, idx2=1, step2=1
# Calculating energy for idx1=2, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=3, step1=1, idx2=0, step2=1
# Calculating energy for idx1=3, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=3, step1=1, idx2=1, step2=1
# Calculating energy for idx1=3, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=3, step1=1, idx2=2, step2=1
# Calculating energy for idx1=3, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=4, step1=1, idx2=0, step2=1
# Calculating energy for idx1=4, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=4, step1=1, idx2=1, step2=1
# Calculating energy for idx1=4, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=4, step1=1, idx2=2, step2=1
# Calculating energy for idx1=4, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=4, step1=1, idx2=3, step2=1
# Calculating energy for idx1=4, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=5, step1=1, idx2=0, step2=1
# Calculating energy for idx1=5, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=5, step1=1, idx2=1, step2=1
# Calculating energy for idx1=5, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=5, step1=1, idx2=2, step2=1
# Calculating energy for idx1=5, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=5, step1=1, idx2=3, step2=1
# Calculating energy for idx1=5, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=5, step1=1, idx2=4, step2=1
# Calculating energy for idx1=5, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=0, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=1, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=2, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=3, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=4, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=6, step1=1, idx2=5, step2=1
# Calculating energy for idx1=6, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=0, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=1, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=2, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=3, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=4, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=5, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=7, step1=1, idx2=6, step2=1
# Calculating energy for idx1=7, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=0, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=1, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=2, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=3, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=4, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=5, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=6, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=8, step1=1, idx2=7, step2=1
# Calculating energy for idx1=8, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=0, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=1, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=2, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=3, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=4, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=5, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=6, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=7, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=9, step1=1, idx2=8, step2=1
# Calculating energy for idx1=9, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=0, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=1, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=2, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=3, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=4, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=5, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=6, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=7, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=8, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=10, step1=1, idx2=9, step2=1
# Calculating energy for idx1=10, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=0, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=1, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=2, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=3, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=4, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=5, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=6, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=7, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=8, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=9, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=11, step1=1, idx2=10, step2=1
# Calculating energy for idx1=11, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=0, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=1, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=2, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=3, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=4, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=5, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=6, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=7, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=8, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=9, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=10, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=12, step1=1, idx2=11, step2=1
# Calculating energy for idx1=12, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=0, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=1, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=2, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=3, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=4, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=5, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=6, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=7, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=8, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=9, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=10, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=11, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=13, step1=1, idx2=12, step2=1
# Calculating energy for idx1=13, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=0, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=1, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=2, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=3, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=4, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=5, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=6, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=7, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=8, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=9, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=10, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=11, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=12, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=14, step1=1, idx2=13, step2=1
# Calculating energy for idx1=14, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=0, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=1, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=2, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=3, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=4, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=5, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=6, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=7, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=8, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=9, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=10, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=11, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=12, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=13, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=15, step1=1, idx2=14, step2=1
# Calculating energy for idx1=15, step1=-1, idx2=14, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=0, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=1, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=2, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=3, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=4, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=5, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=6, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=7, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=8, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=9, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=10, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=11, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=12, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=13, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=14, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=14, step2=-1
# Calculating energy for idx1=16, step1=1, idx2=15, step2=1
# Calculating energy for idx1=16, step1=-1, idx2=15, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=0, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=1, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=2, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=3, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=4, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=5, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=6, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=7, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=8, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=9, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=10, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=11, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=12, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=13, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=14, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=14, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=15, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=15, step2=-1
# Calculating energy for idx1=17, step1=1, idx2=16, step2=1
# Calculating energy for idx1=17, step1=-1, idx2=16, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=0, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=1, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=2, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=3, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=4, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=5, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=6, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=7, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=8, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=9, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=10, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=11, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=12, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=13, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=14, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=14, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=15, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=15, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=16, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=16, step2=-1
# Calculating energy for idx1=18, step1=1, idx2=17, step2=1
# Calculating energy for idx1=18, step1=-1, idx2=17, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=0, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=0, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=1, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=1, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=2, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=2, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=3, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=3, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=4, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=4, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=5, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=5, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=6, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=6, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=7, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=7, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=8, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=8, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=9, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=9, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=10, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=10, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=11, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=11, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=12, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=12, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=13, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=13, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=14, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=14, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=15, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=15, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=16, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=16, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=17, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=17, step2=-1
# Calculating energy for idx1=19, step1=1, idx2=18, step2=1
# Calculating energy for idx1=19, step1=-1, idx2=18, step2=-1
# Calculating energy for idx1=20, step1=1, idx2