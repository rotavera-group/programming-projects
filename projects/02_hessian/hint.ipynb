# %%
# 1. Generate a starting structure from a SMILES string using `protomol`
from protomol import smiles

smi = "C[CH2]"  # SMILES formula for propyl radical

# Generate a geometry for the SMILES formula
geo = smiles.geometry(smi)

# %%
# 2. Optimize the structure with GFN2-xTB using `qcop`
import qcio
import qcop
from protomol import qc

struc = qc.struc.from_geometry(geo)
prog_inp = qcio.ProgramInput(
    structure=struc, calctype="optimization", model={"method": "gfn2"}
)
prog_out = qcop.compute("crest", prog_inp)

equilibrium_structure = prog_out.results.final_structure

# %%
# 3. By displacing the equilibrium structure and running energy calculations,
# calculate the Hessian of the PES at equilibrium.
import numpy
import functools
from protomol import geom
from numpy.typing import ArrayLike


def coordinate_count(geo: geom.Geometry) -> int:
    """Count number of coordinates in geometry.

    (Generic function that could be added to protomol.geom.)

    :param geo: Geometry
    :return: Number of coordinates
    """
    return geom.count(geo) * 3


def displace(geo: geom.Geometry, disp: ArrayLike) -> geom.Geometry:
    """Displace geometry by arbitrary coordinate vector.

    (Generic function that could be added to protomol.geom.)

    :param geo: Geometry
    :param disp: Displacement vector
    :return: Displaced geometry
    """
    geo = geo.model_copy()
    natms = geom.count(geo)
    geo.coordinates = geo.coordinates + numpy.reshape(disp, (natms, 3))
    return geo


def step_displace_coordinate(
    geo: geom.Geometry, idx: int, step: int = 1, step_size: float = 0.005
) -> geom.Geometry:
    """Step-displace geometry along one coordinate.

    (Project-specific helper function that could be added to util.py)

    Displaces a specific coordinate by a certain number of steps in the forward
    (positive) or backward (negative) direction.

    :param geo: Geometry
    :param idx: Flat coordinate index, 0, 1, ..., 3 * n
    :param step: Number of steps to displace (positive or negative)
    :param step_size: Displacement step size
    :return: Geometry
    """
    # Your code goes here...
    # Example:
    #
    #     # input:
    #     geo = geom.Geometry(
    #         symbols=['O', 'H', 'H'],
    #         coordinates=[
    #             [0., 0., 0.],
    #             [1., 0., 0.],
    #             [0., 1., 0.]
    #         ]
    #     )
    #
    #     # function call:
    #     step_displace_coordinate(geo, idx=0, step=-1)
    #
    #     # output:
    #     geom.Geometry(
    #         symbols=['O', 'H', 'H'],
    #         coordinates=[
    #             [0.005, 0., 0.],
    #             [1., 0., 0.],
    #             [0., 1., 0.]
    #         ]
    #     )
    #
    pass


def hessian(
    prog: str, ene_inp: qcio.ProgramInput, step_size: float = 0.005
) -> numpy.ndarray:
    """Calculate Hessian from energy program input.

    :param prog: Program name, e.g. "crest"
    :param ene_inp: Energy program input
    :param step_size: Step size (in Bohr)
    :return: Hessian matrix
    """
    # Your code goes here...

    # To avoid duplicate energy calculations, one can here define a "memoized"
    # function that caches its values
    @functools.cache
    def energy(idx: int = 0, step: int = 0, idx2: int = 0, step2: int = 0):
        # Calculate energy for displacing a specific (pair of) coordinate(s)
        pass
    
    pass


ene_inp = qcio.ProgramInput(
    structure=equilibrium_structure, calctype="energy", model={"method": "gfn2"}
)
hess = hessian("crest", ene_inp=ene_inp)
print(hess)
# Out:
# crest structure=Structure(formula='C2H5') model=Model(method='gfn2') calctype='energy' 0.005
# None

# %%
# 4. Check your answer by calculating the same Hessian directly with `qcop`.
prog_inp = qcio.ProgramInput(
    structure=equilibrium_structure, calctype="hessian", model={"method": "gfn2"}
)
prog_out = qcop.compute("crest", prog_inp)

hessian = prog_out.results.hessian
print(hessian)
# Out:
# [[ 4.7095171e-01  2.2784160e-02 -1.2219600e-03 -2.5140207e-01
#    1.0234190e-02  1.3663350e-02 -6.5026230e-02  2.8110450e-02
#   -6.3665950e-02 -4.7928530e-02  2.3282090e-02  4.1416650e-02
#   -7.6795500e-02 -8.3911460e-02  7.5291600e-03 -1.5519770e-02
#   -1.5654100e-03  1.1651200e-03 -1.4272540e-02  9.6275000e-04
#    1.0360200e-03]
#  [ 2.2784160e-02  5.1256117e-01 -1.2814230e-02 -2.1584100e-03
#   -6.8693540e-02  4.6363500e-03  3.4292950e-02 -8.5285830e-02
#    8.0699640e-02  3.1423160e-02 -1.0745294e-01 -9.4245280e-02
#   -8.3488020e-02 -2.5029271e-01  2.0980400e-02 -2.4293700e-02
#   -1.5047000e-04  2.2376700e-03  2.1487250e-02 -6.1479000e-04
#   -1.4427600e-03]
#  [-1.2219600e-03 -1.2814230e-02  4.3522458e-01  1.3339110e-02
#    3.8232800e-03 -3.7790550e-02 -7.2044620e-02  8.0714060e-02
#   -1.8347983e-01  5.0657700e-02 -9.3542740e-02 -1.7008919e-01
#    7.7722900e-03  2.1121530e-02 -4.7122780e-02  3.8637600e-03
#   -2.4706000e-04 -2.0841000e-03 -2.3379100e-03  9.6401000e-04
#    5.3979400e-03]
#  [-2.5140207e-01 -2.1584100e-03  1.3339110e-02  5.4387263e-01
#   -1.4574420e-02 -2.9684410e-02 -2.5763830e-02  9.4851100e-03
#   -6.2073000e-03 -2.3829520e-02  1.0690820e-02  9.8393200e-03
#   -1.8903200e-02 -4.0516400e-03  2.0961600e-03 -1.1526208e-01
#   -1.1942789e-01  2.2370210e-02 -1.0852345e-01  1.2018921e-01
#   -1.1677770e-02]
#  [ 1.0234190e-02 -6.8693540e-02  3.8232800e-03 -1.4574420e-02
#    5.6742693e-01 -7.3187970e-02  1.5960430e-02 -4.2083000e-04
#    3.4825000e-04  1.7672580e-02 -1.0619000e-04 -1.7206700e-03
#   -2.9246610e-02 -8.6887000e-04  2.1473300e-03 -1.1875631e-01
#   -2.4174284e-01  3.8462740e-02  1.1867286e-01 -2.5562286e-01
#    3.0136890e-02]
#  [ 1.3663350e-02  4.6363500e-03 -3.7790550e-02 -2.9684410e-02
#   -7.3187970e-02  5.6405180e-02 -1.8692960e-02  3.7944000e-04
#    4.6189200e-03  1.9642360e-02 -9.8624000e-04  1.5442300e-03
#    3.9275600e-03  5.8535000e-04 -1.1296000e-04  2.2487450e-02
#    3.9057880e-02 -1.5395870e-02 -1.1382480e-02  2.9507300e-02
#   -9.3210400e-03]
#  [-6.5026230e-02  3.4292950e-02 -7.2044620e-02 -2.5763830e-02
#    1.5960430e-02 -1.8692960e-02  8.5281050e-02 -4.3896460e-02
#    7.9071200e-02  4.4079500e-03 -1.7890600e-03  4.3308800e-03
#    4.3547500e-03 -4.8147800e-03  8.4361800e-03  7.5003000e-04
#    4.7808000e-04  3.4511000e-04 -4.0840200e-03 -2.4430000e-04
#   -1.4496500e-03]
#  [ 2.8110450e-02 -8.5285830e-02  8.0714060e-02  9.4851100e-03
#   -4.2083000e-04  3.7944000e-04 -4.3896460e-02  9.5182290e-02
#   -9.3234360e-02 -4.2138600e-03  6.5720700e-03 -1.4696560e-02
#    9.7709300e-03 -1.6898370e-02  2.6311830e-02 -3.5409000e-04
#    5.1117000e-04  1.5121000e-04  1.0281100e-03  2.4730000e-04
#    3.2481000e-04]
#  [-6.3665950e-02  8.0699640e-02 -1.8347983e-01 -6.2073000e-03
#    3.4825000e-04  4.6189200e-03  7.9071200e-02 -9.3234360e-02
#    2.1644637e-01 -8.6667800e-03  9.5369500e-03 -3.2344320e-02
#   -1.2312000e-03  3.8424000e-03 -4.2644700e-03  1.8775000e-04
#   -8.6290000e-05  5.7060000e-04  6.1512000e-04 -1.0606900e-03
#   -1.5438900e-03]
#  [-4.7928530e-02  3.1423160e-02  5.0657700e-02 -2.3829520e-02
#    1.7672580e-02  1.9642360e-02  4.4079500e-03 -4.2138600e-03
#   -8.6667800e-03  6.6704100e-02 -3.8938330e-02 -5.4519940e-02
#    3.3855200e-03 -6.3935700e-03 -8.1219700e-03  4.3483000e-04
#    3.0263000e-04 -4.8069000e-04 -3.2360700e-03  1.4883000e-04
#    1.5176500e-03]
#  [ 2.3282090e-02 -1.0745294e-01 -9.3542740e-02  1.0690820e-02
#   -1.0619000e-04 -9.8624000e-04 -1.7890600e-03  6.5720700e-03
#    9.5369500e-03 -3.8938330e-02  1.2218212e-01  1.1101908e-01
#    6.2734200e-03 -2.1605510e-02 -2.5221210e-02 -3.2429000e-04
#    1.8336000e-04 -5.6159000e-04  7.7473000e-04  1.5171000e-04
#   -2.9567000e-04]
#  [ 4.1416650e-02 -9.4245280e-02 -1.7008919e-01  9.8393200e-03
#   -1.7206700e-03  1.5442300e-03  4.3308800e-03 -1.4696560e-02
#   -3.2344320e-02 -5.4519940e-02  1.1101908e-01  2.0166962e-01
#   -5.6432000e-04 -9.1253000e-04  6.2542000e-04 -9.2600000e-05
#    6.8390000e-05  6.6069000e-04 -4.8831000e-04  4.5368000e-04
#   -2.0975100e-03]
#  [-7.6795500e-02 -8.3488020e-02  7.7722900e-03 -1.8903200e-02
#   -2.9246610e-02  3.9275600e-03  4.3547500e-03  9.7709300e-03
#   -1.2312000e-03  3.3855200e-03  6.2734200e-03 -5.6432000e-04
#    9.3103160e-02  9.7973670e-02 -1.0380270e-02 -6.3708000e-03
#   -1.1318000e-04  4.1019000e-04  1.1969800e-03 -1.1567800e-03
#    7.0530000e-05]
#  [-8.3911460e-02 -2.5029271e-01  2.1121530e-02 -4.0516400e-03
#   -8.6887000e-04  5.8535000e-04 -4.8147800e-03 -1.6898370e-02
#    3.8424000e-03 -6.3935700e-03 -2.1605510e-02 -9.1253000e-04
#    9.7973670e-02  2.8669218e-01 -2.4211620e-02  1.8768000e-04
#    1.4668100e-03 -1.8879000e-04  1.1040600e-03  1.6183400e-03
#   -1.8315000e-04]
#  [ 7.5291600e-03  2.0980400e-02 -4.7122780e-02  2.0961600e-03
#    2.1473300e-03 -1.1296000e-04  8.4361800e-03  2.6311830e-02
#   -4.2644700e-03 -8.1219700e-03 -2.5221210e-02  6.2542000e-04
#   -1.0380270e-02 -2.4211620e-02  4.8975770e-02  6.5622000e-04
#    2.4704000e-04  2.4979400e-03 -2.6274000e-04 -2.8205000e-04
#   -6.2708000e-04]
#  [-1.5519770e-02 -2.4293700e-02  3.8637600e-03 -1.1526208e-01
#   -1.1875631e-01  2.2487450e-02  7.5003000e-04 -3.5409000e-04
#    1.8775000e-04  4.3483000e-04 -3.2429000e-04 -9.2600000e-05
#   -6.3708000e-03  1.8768000e-04  6.5622000e-04  1.2965270e-01
#    1.3247844e-01 -2.5360800e-02  6.2895700e-03  1.1048800e-02
#   -1.7618600e-03]
#  [-1.5654100e-03 -1.5047000e-04 -2.4706000e-04 -1.1942789e-01
#   -2.4174284e-01  3.9057880e-02  4.7808000e-04  5.1117000e-04
#   -8.6290000e-05  3.0263000e-04  1.8336000e-04  6.8390000e-05
#   -1.1318000e-04  1.4668100e-03  2.4704000e-04  1.3247844e-01
#    2.6190202e-01 -4.3114890e-02 -1.2123680e-02 -2.2133290e-02
#    4.0704300e-03]
#  [ 1.1651200e-03  2.2376700e-03 -2.0841000e-03  2.2370210e-02
#    3.8462740e-02 -1.5395870e-02  3.4511000e-04  1.5121000e-04
#    5.7060000e-04 -4.8069000e-04 -5.6159000e-04  6.6069000e-04
#    4.1019000e-04 -1.8879000e-04  2.4979400e-03 -2.5360800e-02
#   -4.3114890e-02  1.1598650e-02  1.5618300e-03  3.0119900e-03
#    2.1736800e-03]
#  [-1.4272540e-02  2.1487250e-02 -2.3379100e-03 -1.0852345e-01
#    1.1867286e-01 -1.1382480e-02 -4.0840200e-03  1.0281100e-03
#    6.1512000e-04 -3.2360700e-03  7.7473000e-04 -4.8831000e-04
#    1.1969800e-03  1.1040600e-03 -2.6274000e-04  6.2895700e-03
#   -1.2123680e-02  1.5618300e-03  1.2263059e-01 -1.3098114e-01
#    1.2287570e-02]
#  [ 9.6275000e-04 -6.1479000e-04  9.6401000e-04  1.2018921e-01
#   -2.5562286e-01  2.9507300e-02 -2.4430000e-04  2.4730000e-04
#   -1.0606900e-03  1.4883000e-04  1.5171000e-04  4.5368000e-04
#   -1.1567800e-03  1.6183400e-03 -2.8205000e-04  1.1048800e-02
#   -2.2133290e-02  3.0119900e-03 -1.3098114e-01  2.7632981e-01
#   -3.2603610e-02]
#  [ 1.0360200e-03 -1.4427600e-03  5.3979400e-03 -1.1677770e-02
#    3.0136890e-02 -9.3210400e-03 -1.4496500e-03  3.2481000e-04
#   -1.5438900e-03  1.5176500e-03 -2.9567000e-04 -2.0975100e-03
#    7.0530000e-05 -1.8315000e-04 -6.2708000e-04 -1.7618600e-03
#    4.0704300e-03  2.1736800e-03  1.2287570e-02 -3.2603610e-02
#    6.0482300e-03]]
